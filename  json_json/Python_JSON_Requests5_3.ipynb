# %% [markdown]
# # Библиотека Requests

# %% [markdown]
# HTTP запросы имеют следующую структуру:
#
# ![P6.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# HTTP ответы на отправленные запросы имеют несколько другую струк-
# туру:
# ![P7.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# Основные поддерживаемые методы:
# * GET - получение (чтение) данных ресурса;
# * POST - создание ресурса;
# * PUT — обновление ресурса;
# * HEAD - получение информации о ресурсе;
# * DELETE - удаление ресурса.

# %%
import requests # импортируем библиотеку

# %% [markdown]
# https://itmo.ru/ru/department_units/obschaya_struktura_universiteta.htm
# ![P2.jpg](data:image/jpeg;base64,...)

# %%
page = requests.get('https://itmo.ru/ru/department_units/obschaya_struktura_universiteta.htm')
print(page.text)
# Out:
# <!DOCTYPE html>
# <html lang="ru" xmlns="http://www.w3.org/1999/xhtml" xml:lang="ru">
# <head>
# <!--    <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':-->
# <!--                new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],-->
# <!--            j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=-->
# <!--            'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);-->
# <!--        })(window,document,'script','dataLayer','GTM-WNJ7SMC');</script>-->
# 	    <script
#             src="https://browser.sentry-cdn.com/6.16.1/bundle.tracing.min.js"
#             integrity="sha384-hySah00SvKME+98UjlzyfP852AXjPPTh2vgJu26gFcwTlZ02/zm82SINaKTKwIX2"
#             crossorigin="anonymous"
#     ></script>
#     <script>
#         Sentry.init({
#           dsn: 'https://91bfaea5c4e240f0802e01ea2046e82f@sentry-intern.itmo.dev/17',
#           release: `itmo_ru_frontend@d1f546d`,
# ...

# %%
from bs4 import BeautifulSoup # подключение библиотеки

# %%
html_doc = BeautifulSoup(page.text, 'html.parser')
for tag in html_doc.find('h1', text = 'Основные образовательные и научные подразделения').findNext('div').find_all('ul', recursive = False):
 print(tag.find('a').text)
# Out:
# Мегафакультет компьютерных технологий и управления
# Физико-технический мегафакультет
# Мегафакультет трансляционных информационных технологий
# Мегафакультет наук о жизни
# Факультет технологического менеджмента и инноваций
# Институт  "Высшая инженерно-техническая школа"
# Высшая школа цифровой культуры
# Военный учебный центр
# Национальный центр когнитивных разработок
# Национальный центр квантового интернета
# Образовательный центр "Энергоэффективные инженерные системы"
# Школа разработки видеоигр
# Инновационный индустриальный центр ПАО "Газпром нефть" - Университет ИТМО
# <ipython-input-4-479b1f8f79d4>:2: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   for tag in html_doc.find('h1', text = 'Основные образовательные и научные подразделения').findNext('div').find_all('ul', recursive = False):
